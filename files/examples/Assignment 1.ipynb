# %% [markdown]
# # Assignment 1: NeoPixel LED with MicroPython
#
# This notebook demonstrates how to configure and control a single **NeoPixel LED** using MicroPython.
# We will explore setting a static color, cycling through rainbow colors, and applying a breathing effect.

# %%
import machine
import neopixel
import time

# %%
'''
Configure the NeoPixel LED located on GPIO 2.
Number of pixels is 1.

For docs refer to:
https://docs.micropython.org/en/latest/esp8266/tutorial/neopixel.html
'''

neopixel_led = ...

# %%
def set_color(r, g, b):
    """Set the NeoPixel to a specific RGB color"""
    ...

def clear_led():
    """Turn off the LED"""
    ...

set_color(255,0,0)
time.sleep(1)
set_color(0,255,0)
time.sleep(1)
set_color(0,0,255)
time.sleep(1)
clear_led()

# %%
def rainbow_cycle():
    """Cycle through rainbow colors"""
    ...

rainbow_cycle()

# %%
def breathing_effect(r, g, b, duration=2, steps=50):
    """
    Create a breathing effect with the specified color
    duration → total time for fade in + fade out
    steps → number of discrete brightness levels
    """
    # Fade in
    ...
    # Fade out
    ...

breathing_effect(255,0,0)
